# %%
from crystfel_stream_parser.engine import StreamParser

# %%
# path_stream = 'userdata/mfx13016_0036.stream'
# path_stream = 'userdata/mfx13016/cwang31/psocake/r0033/mfx13016_0033_zhen2021.stream'
path_stream = 'userdata/cxic0415/cwang31/psocake/r0101/cxic0415_0101.stream'
stream_parser = StreamParser(path_stream)

# %%
stream_parser.parse(num_cpus = 4)
# Out:
# 2024-02-05 12:36:56,096	INFO worker.py:1724 -- Started a local Ray instance.

# %%
len(stream_parser.stream_record_list)
# Out:
# 2088

# %%
stream_parser.stream_record_list[0]
# Out:
# {'metadata': {'hit': '1',
#   'indexed_by': 'mosflm-latt-cell',
#   'n_indexing_tries': '1',
#   'photon_energy_eV': '12688.890590',
#   'beam_divergence': '0.00e+00 rad',
#   'beam_bandwidth': '1.00e-08 (fraction)',
#   'hdf5/LCLS/detector_1/EncoderValue': '-450.003400',
#   'hdf5/LCLS/photon_energy_eV': '12688.890590',
#   'average_camera_length': '0.138695 m',
#   'num_peaks': '386',
#   'num_saturated_peaks': '0',
#   'peak_resolution': '5.261914 nm^-1 or 1.900449 A',
#   'Image filename': './cxic0415/cwang31/psocake/r0101/cxic0415_0101_train.cxi',
#   'Event': '//13',
#   'Image serial number': '14'},
#  'found peaks': {'q0a1': [[258.5, 23.5, 3.67, 10564.81],
#    [225.5, 79.5, 3.2, 55459.32],
#    [210.5, 91.5, 3.08, 3468.94],
#    [291.5, 112.5, 3.26, 26116.58],
#    [232.5, 159.5, 2.72, 6502.62],
#    [287.5, 172.5, 2.9, 3100.09]],
#   'q0a0': [[153.5, 25.5, 3.38, 2989.89],
#    [13.5, 51.5, 3.09, 7962.69],
#    [151.5, 55.5, 3.16, 2392.35],
# ...

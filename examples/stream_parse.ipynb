# %%
from crystfel_stream_parser.engine import StreamParser

# %%
path_stream = 'userdata/mfx13016_0036.stream'
stream_parser = StreamParser(path_stream)

# %%
# stream_parser.parse()

# %%
stream_parser.parallel_parse(num_cpus = 10)
# Out:
# 2024-02-04 17:17:57,516	INFO worker.py:1724 -- Started a local Ray instance.

# %%
len(stream_parser.stream_record_list)
# Out:
# 2039

# %%
[ record for record in stream_parser.stream_record_list if record['metadata']['Event'] == '//5' and record['metadata']['Image filename'] == './mfx13016/cwang31/psocake/r0036/mfx13016_0036_1.cxi' ]
# Out:
# [{'metadata': {'hit': '1',
#    'indexed_by': 'mosflm-nolatt-nocell',
#    'n_indexing_tries': '6',
#    'photon_energy_eV': '9282.959068',
#    'beam_divergence': '0.00e+00 rad',
#    'beam_bandwidth': '1.00e-08 (fraction)',
#    'hdf5/LCLS/detector_1/EncoderValue': '0.000000',
#    'hdf5/LCLS/photon_energy_eV': '9282.959068',
#    'average_camera_length': '0.084800 m',
#    'num_peaks': '46',
#    'peak_resolution': '4.828525 nm^-1 or 2.071026 A',
#    'Image filename': './mfx13016/cwang31/psocake/r0036/mfx13016_0036_1.cxi',
#    'Event': '//5',
#    'Image serial number': '11'},
#   'found peaks': [{'FLOAT': ['612.50', '331.50', '4.82', '351.12'],
#     'DET_PANEL': ['p0a0']},
#    {'FLOAT': ['536.50', '377.50', '4.83', '2026.64'], 'DET_PANEL': ['p0a0']},
#    {'FLOAT': ['916.50', '528.50', '3.25', '410.67'], 'DET_PANEL': ['p0a0']},
#    {'FLOAT': ['876.50', '614.50', '2.75', '315.76'], 'DET_PANEL': ['p0a0']},
# ...
